# %%
import sys
print("Python path:", sys.executable)
print("Should contain: /home/yam/Documents/PhD/python/phd_env")

import numpy as np
print("NumPy version:", np.__version__)
print("✅ Environment working!")
# Out:
# Python path: /home/yam/Documents/PhD/python/phd_env/bin/python
# Should contain: /home/yam/Documents/PhD/python/phd_env
# NumPy version: 2.4.0
# ✅ Environment working!
