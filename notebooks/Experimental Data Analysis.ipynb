# %%
#1

import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 2*np.pi, 1000)
y = np.sin(x)

plt.figure(figsize=(6,4))
plt.plot(x, y, label="sin(x)")
plt.xlabel("x")
plt.ylabel("Amplitude")
plt.legend()
plt.grid(True)
plt.savefig("sine_wave.png", dpi=300)
plt.show()
#2
import numpy as np
import matplotlib.pyplot as plt

# Data
x = np.linspace(0, 2*np.pi, 1000)
y = np.sin(x)

# Plot
plt.figure(figsize=(6,4))
plt.plot(x, y, label="sin(x)")
plt.xlabel("x")
plt.ylabel("Amplitude")
plt.title("Sine Function")
plt.legend()
plt.grid(True)

# Save figure (optional but recommended for papers)
plt.savefig("sine_wave.png", dpi=300)

# Show figure in notebook
plt.show()
#3
import pandas as pd

data = pd.read_csv("../data/data.csv")
data
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

x = data['x_cm']
y = data['y_mV']
y_err = data['y_error_mV']

def linear_model(x, a, b):
    return a*x + b

params, cov = curve_fit(linear_model, x, y, sigma=y_err, absolute_sigma=True)
a, b = params

x_fit = np.linspace(min(x), max(x), 200)
y_fit = linear_model(x_fit, a, b)

plt.errorbar(x, y, yerr=y_err, fmt='o', capsize=5, label='Experimental data')
plt.plot(x_fit, y_fit, 'r-', label=f'Fit: y={a:.2f}x + {b:.2f}')
plt.xlabel("x (cm)")
plt.ylabel("y (mV)")
plt.title("Experimental Data Analysis")
plt.legend()
plt.grid(True)
plt.savefig("experimental_fit.png", dpi=300)
plt.show()

# %%
import sys
sys.executable
# Out:
# '/home/yam/physics-python/phd_env/bin/python'
